# %% [markdown]
# # Project - COVID-19 Analysis [EDA & Visualization]

# %% [markdown]
# - You can find the full project at: https://ourworldindata.org/coronavirus
# - Daily-updated dataset link: https://covid.ourworldindata.org/data/owid-covid-data.csv
# - We'll be exploring the dataset from: https://covid.ourworldindata.org
# - Dashboard Example: https://coronavirus.jhu.edu/map.html

# %% [markdown]
# ## DATA UNDERSTANDING

# %% [markdown]
# ### Importing libraries & data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
sns.set()

# %%
df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 378590      ZWE    Africa     Zimbabwe  2024-02-07     266319.0        0.0
# 378591      ZWE    Africa     Zimbabwe  2024-02-08     266319.0        0.0
# 378592      ZWE    Africa     Zimbabwe  2024-02-09     266319.0        0.0
# 378593      ZWE    Africa     Zimbabwe  2024-02-10     266319.0        0.0
# 378594      ZWE    Africa     Zimbabwe  2024-02-11     266328.0        9.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 378590               4.429        5737.0         0.0                  0.0
# 378591               4.429        5737.0         0.0                  0.0
# 378592               4.429        5737.0         0.0                  0.0
# 378593               4.429        5737.0         0.0                  0.0
# 378594               1.286        5737.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 378590  ...          30.7                  36.791                         1.7
# 378591  ...          30.7                  36.791                         1.7
# 378592  ...          30.7                  36.791                         1.7
# 378593  ...          30.7                  36.791                         1.7
# 378594  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 378590            61.49                    0.571  16320539.0
# 378591            61.49                    0.571  16320539.0
# 378592            61.49                    0.571  16320539.0
# 378593            61.49                    0.571  16320539.0
# 378594            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 378590                                   NaN                          NaN
# 378591                                   NaN                          NaN
# 378592                                   NaN                          NaN
# 378593                                   NaN                          NaN
# 378594                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 378590               NaN                                      NaN
# 378591               NaN                                      NaN
# 378592               NaN                                      NaN
# 378593               NaN                                      NaN
# 378594               NaN                                      NaN
#
# [378595 rows x 67 columns]

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 378590      ZWE    Africa  Zimbabwe  2024-02-07     266319.0        0.0
# 378591      ZWE    Africa  Zimbabwe  2024-02-08     266319.0        0.0
# 378592      ZWE    Africa  Zimbabwe  2024-02-09     266319.0        0.0
# 378593      ZWE    Africa  Zimbabwe  2024-02-10     266319.0        0.0
# 378594      ZWE    Africa  Zimbabwe  2024-02-11     266328.0        9.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 378590               4.429        5737.0         0.0                  0.0
# 378591               4.429        5737.0         0.0                  0.0
# 378592               4.429        5737.0         0.0                  0.0
# 378593               4.429        5737.0         0.0                  0.0
# 378594               1.286        5737.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 378590  ...          30.7                  36.791                         1.7
# 378591  ...          30.7                  36.791                         1.7
# 378592  ...          30.7                  36.791                         1.7
# 378593  ...          30.7                  36.791                         1.7
# 378594  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 378590            61.49                    0.571  16320539.0
# 378591            61.49                    0.571  16320539.0
# 378592            61.49                    0.571  16320539.0
# 378593            61.49                    0.571  16320539.0
# 378594            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 378590                                   NaN                          NaN
# 378591                                   NaN                          NaN
# 378592                                   NaN                          NaN
# 378593                                   NaN                          NaN
# 378594                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 378590               NaN                                      NaN
# 378591               NaN                                      NaN
# 378592               NaN                                      NaN
# 378593               NaN                                      NaN
# 378594               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.sample(12)
# Out:
#        iso_code      continent                  location        date  \
# 256569      PLW        Oceania                     Palau  2020-10-25
# 142242      GUY  South America                    Guyana  2023-09-24
# 203314      MLT         Europe                     Malta  2020-04-25
# 22865       AZE           Asia                Azerbaijan  2021-01-01
# 341073      TON        Oceania                     Tonga  2023-04-03
# 268163      PCN        Oceania                  Pitcairn  2023-10-31
# 304540      SGP           Asia                 Singapore  2021-05-10
# 61813       CAF         Africa  Central African Republic  2020-10-30
# 145485      HND  North America                  Honduras  2020-04-05
# 291917      WSM        Oceania                     Samoa  2023-03-15
# 237625      NIC  North America                 Nicaragua  2023-11-21
# 283241      SHN         Africa              Saint Helena  2024-01-27
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 256569          NaN        0.0               0.000           NaN         0.0
# 142242      73653.0        7.0               1.000        1299.0         0.0
# 203314        431.0        0.0               6.286           3.0         0.0
# 22865      211764.0        0.0            2334.571        2416.0         0.0
# 341073      16814.0        0.0               0.000          12.0         0.0
# 268163          4.0        0.0               0.000           NaN         0.0
# 304540      61359.0        0.0              20.143          31.0         0.0
# 61813        5703.0        0.0               0.857          62.0         0.0
# 145485        264.0      197.0              28.143          15.0        14.0
# 291917      16427.0        0.0               0.000          31.0         0.0
# 237625      15713.0        0.0               0.000         245.0         0.0
# 283241       2166.0        0.0               0.000           NaN         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 256569                0.000  ...          22.7                     NaN
# 142242                0.000  ...           NaN                  77.159
# 203314                0.000  ...          30.2                     NaN
# 22865                40.429  ...          42.5                  83.241
# 341073                0.000  ...          44.4                     NaN
# 268163                0.000  ...           NaN                     NaN
# 304540                0.000  ...          28.3                     NaN
# 61813                 0.000  ...           NaN                  16.603
# 145485                2.000  ...           NaN                  84.169
# 291917                0.286  ...          38.1                     NaN
# 237625                0.000  ...           NaN                     NaN
# 283241                0.000  ...           NaN                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 256569                       4.800            73.70                    0.826
# 142242                       1.600            69.91                    0.682
# 203314                       4.485            82.53                    0.895
# 22865                        4.700            73.00                    0.756
# 341073                       2.600            70.91                    0.725
# 268163                         NaN              NaN                      NaN
# 304540                       2.400            83.62                    0.938
# 61813                        1.000            53.28                    0.397
# 145485                       0.700            75.27                    0.634
# 291917                         NaN            73.32                    0.715
# 237625                       0.900            74.48                    0.660
# 283241                         NaN            80.56                      NaN
#
#         population  excess_mortality_cumulative_absolute  \
# 256569     18084.0                                   NaN
# 142242    808727.0                                   NaN
# 203314    533293.0                                   NaN
# 22865   10358078.0                                   NaN
# 341073    106867.0                                   NaN
# 268163        47.0                                   NaN
# 304540   5637022.0                                   NaN
# 61813    5579148.0                                   NaN
# 145485  10432858.0                                   NaN
# 291917    222390.0                                   NaN
# 237625   6948395.0                                   NaN
# 283241      5401.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 256569                          NaN               NaN
# 142242                          NaN               NaN
# 203314                          NaN               NaN
# 22865                           NaN               NaN
# 341073                          NaN               NaN
# 268163                          NaN               NaN
# 304540                          NaN               NaN
# 61813                           NaN               NaN
# 145485                          NaN               NaN
# 291917                          NaN               NaN
# 237625                          NaN               NaN
# 283241                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 256569                                      NaN
# 142242                                      NaN
# 203314                                      NaN
# 22865                                       NaN
# 341073                                      NaN
# 268163                                      NaN
# 304540                                      NaN
# 61813                                       NaN
# 145485                                      NaN
# 291917                                      NaN
# 237625                                      NaN
# 283241                                      NaN
#
# [12 rows x 67 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'total_tests',
#  'new_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'total_boosters_per_hundred',
#  'new_vaccinations_smoothed_per_million',
#  'new_people_vaccinated_smoothed',
#  'new_people_vaccinated_smoothed_per_hundred',
#  'stringency_index',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'extreme_poverty',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'female_smokers',
#  'male_smokers',
#  'handwashing_facilities',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index',
#  'population',
#  'excess_mortality_cumulative_absolute',
#  'excess_mortality_cumulative',
#  'excess_mortality',
#  'excess_mortality_cumulative_per_million']

# %%
df.shape
# Out:
# (378595, 67)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378595 entries, 0 to 378594
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    378595 non-null  object
#  1   continent                                   360495 non-null  object
#  2   location                                    378595 non-null  object
#  3   date                                        378595 non-null  object
#  4   total_cases                                 339793 non-null  float64
#  5   new_cases                                   367810 non-null  float64
#  6   new_cases_smoothed                          366580 non-null  float64
#  7   total_deaths                                317779 non-null  float64
#  8   new_deaths                                  367817 non-null  float64
#  9   new_deaths_smoothed                         366587 non-null  float64
#  10  total_cases_per_million                     339793 non-null  float64
#  11  new_cases_per_million                       367810 non-null  float64
#  12  new_cases_smoothed_per_million              366580 non-null  float64
#  13  total_deaths_per_million                    317779 non-null  float64
#  14  new_deaths_per_million                      367817 non-null  float64
#  15  new_deaths_smoothed_per_million             366587 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                38439 non-null   float64
#  18  icu_patients_per_million                    38439 non-null   float64
#  19  hosp_patients                               39940 non-null   float64
#  20  hosp_patients_per_million                   39940 non-null   float64
#  21  weekly_icu_admissions                       10595 non-null   float64
#  22  weekly_icu_admissions_per_million           10595 non-null   float64
#  23  weekly_hosp_admissions                      23985 non-null   float64
#  24  weekly_hosp_admissions_per_million          23985 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          82705 non-null   float64
#  35  people_vaccinated                           78655 non-null   float64
#  36  people_fully_vaccinated                     75512 non-null   float64
#  37  total_boosters                              50800 non-null   float64
#  38  new_vaccinations                            68504 non-null   float64
#  39  new_vaccinations_smoothed                   189193 non-null  float64
#  40  total_vaccinations_per_hundred              82705 non-null   float64
#  41  people_vaccinated_per_hundred               78655 non-null   float64
#  42  people_fully_vaccinated_per_hundred         75512 non-null   float64
#  43  total_boosters_per_hundred                  50800 non-null   float64
#  44  new_vaccinations_smoothed_per_million       189193 non-null  float64
#  45  new_people_vaccinated_smoothed              186680 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  186680 non-null  float64
#  47  stringency_index                            197292 non-null  float64
#  48  population_density                          321756 non-null  float64
#  49  median_age                                  299121 non-null  float64
#  50  aged_65_older                               288778 non-null  float64
#  51  aged_70_older                               296123 non-null  float64
#  52  gdp_per_capita                              293275 non-null  float64
#  53  extreme_poverty                             189032 non-null  float64
#  54  cardiovasc_death_rate                       293842 non-null  float64
#  55  diabetes_prevalence                         308969 non-null  float64
#  56  female_smokers                              220542 non-null  float64
#  57  male_smokers                                217544 non-null  float64
#  58  handwashing_facilities                      143950 non-null  float64
#  59  hospital_beds_per_thousand                  259516 non-null  float64
#  60  life_expectancy                             348588 non-null  float64
#  61  human_development_index                     284985 non-null  float64
#  62  population                                  378595 non-null  float64
#  63  excess_mortality_cumulative_absolute        13113 non-null   float64
#  64  excess_mortality_cumulative                 13113 non-null   float64
#  65  excess_mortality                            13113 non-null   float64
#  66  excess_mortality_cumulative_per_million     13113 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 193.5+ MB

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  3.397930e+05  3.678100e+05        3.665800e+05  3.177790e+05
# mean   7.234009e+06  8.926184e+03        8.955334e+03  8.908641e+04
# std    4.329032e+07  2.424453e+05        9.141388e+04  4.530218e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    9.106000e+03  0.000000e+00        0.000000e+00  1.330000e+02
# 50%    7.777200e+04  0.000000e+00        1.871400e+01  1.376000e+03
# 75%    8.341830e+05  0.000000e+00        4.255710e+02  1.232050e+04
# max    7.746314e+08  4.423623e+07        6.319461e+06  7.031216e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  367817.000000        366587.000000            339793.000000
# mean       79.404663            79.666593            110034.589912
# std      1440.850695           540.491077            158194.118604
# min         0.000000             0.000000                 0.000000
# 25%         0.000000             0.000000              2885.735000
# 50%         0.000000             0.143000             31845.405000
# 75%         0.000000             4.286000            152290.808000
# max    103719.000000         14817.000000            764083.456000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          367810.000000                   366580.000000
# mean              135.560187                      136.001049
# std              1561.856458                      577.746712
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.000000
# 50%                 0.000000                        4.727000
# 75%                 0.000000                       71.792000
# max            240325.866000                    34332.267000
#
#        total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# count             317779.000000  ...  217544.00000           143950.000000
# mean                 908.135971  ...      32.91023               50.790468
# std                 1124.964393  ...      13.57241               31.953478
# min                    0.000000  ...       7.70000                1.188000
# 25%                   64.716000  ...      22.60000               20.859000
# 50%                  404.028000  ...      33.10000               49.839000
# 75%                 1445.813000  ...      41.30000               82.502000
# max                 6507.656000  ...      78.10000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count               259516.000000    348588.000000            284985.000000
# mean                     3.097414        73.713166                 0.722566
# std                      2.548260         7.395344                 0.149003
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        69.590000                 0.602000
# 50%                      2.500000        75.050000                 0.740000
# 75%                      4.200000        79.460000                 0.829000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  3.785950e+05                          1.311300e+04
# mean   1.290738e+08                          5.460328e+04
# std    6.627841e+08                          1.513266e+05
# min    4.700000e+01                         -3.772610e+04
# 25%    4.490020e+05                          1.708000e+02
# 50%    5.882259e+06                          6.654600e+03
# 75%    2.830170e+07                          3.875370e+04
# max    7.975105e+09                          1.327828e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                 13113.000000      13113.000000
# mean                      9.752126         10.987011
# std                      11.973323         24.567275
# min                     -44.230000        -95.920000
# 25%                       1.990000         -1.520000
# 50%                       8.150000          5.650000
# 75%                      15.060000         15.720000
# max                      76.620000        377.700000
#
#        excess_mortality_cumulative_per_million
# count                             13113.000000
# mean                               1768.995621
# std                                1986.543673
# min                               -2936.453100
# 25%                                 115.941200
# 50%                                1237.869900
# 75%                                2871.024400
# max                               10293.515000
#
# [8 rows x 62 columns]

# %%
df.describe().T
# Out:
#                                             count          mean           std  \
# total_cases                              339793.0  7.234009e+06  4.329032e+07
# new_cases                                367810.0  8.926184e+03  2.424453e+05
# new_cases_smoothed                       366580.0  8.955334e+03  9.141388e+04
# total_deaths                             317779.0  8.908641e+04  4.530218e+05
# new_deaths                               367817.0  7.940466e+01  1.440851e+03
# ...                                           ...           ...           ...
# population                               378595.0  1.290738e+08  6.627841e+08
# excess_mortality_cumulative_absolute      13113.0  5.460328e+04  1.513266e+05
# excess_mortality_cumulative               13113.0  9.752126e+00  1.197332e+01
# excess_mortality                          13113.0  1.098701e+01  2.456728e+01
# excess_mortality_cumulative_per_million   13113.0  1.768996e+03  1.986544e+03
#
#                                                 min           25%  \
# total_cases                                  1.0000    9106.00000
# new_cases                                    0.0000       0.00000
# new_cases_smoothed                           0.0000       0.00000
# total_deaths                                 1.0000     133.00000
# new_deaths                                   0.0000       0.00000
# ...                                             ...           ...
# population                                  47.0000  449002.00000
# excess_mortality_cumulative_absolute    -37726.0980     170.80003
# excess_mortality_cumulative                -44.2300       1.99000
# excess_mortality                           -95.9200      -1.52000
# excess_mortality_cumulative_per_million  -2936.4531     115.94120
#
#                                                   50%           75%  \
# total_cases                              7.777200e+04  8.341830e+05
# new_cases                                0.000000e+00  0.000000e+00
# new_cases_smoothed                       1.871400e+01  4.255710e+02
# total_deaths                             1.376000e+03  1.232050e+04
# new_deaths                               0.000000e+00  0.000000e+00
# ...                                               ...           ...
# population                               5.882259e+06  2.830170e+07
# excess_mortality_cumulative_absolute     6.654600e+03  3.875370e+04
# excess_mortality_cumulative              8.150000e+00  1.506000e+01
# excess_mortality                         5.650000e+00  1.572000e+01
# excess_mortality_cumulative_per_million  1.237870e+03  2.871024e+03
#
#                                                   max
# total_cases                              7.746314e+08
# new_cases                                4.423623e+07
# new_cases_smoothed                       6.319461e+06
# total_deaths                             7.031216e+06
# new_deaths                               1.037190e+05
# ...                                               ...
# population                               7.975105e+09
# excess_mortality_cumulative_absolute     1.327828e+06
# excess_mortality_cumulative              7.662000e+01
# excess_mortality                         3.777000e+02
# excess_mortality_cumulative_per_million  1.029351e+04
#
# [62 rows x 8 columns]

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 378590      ZWE    Africa     Zimbabwe  2024-02-07     266319.0        0.0
# 378591      ZWE    Africa     Zimbabwe  2024-02-08     266319.0        0.0
# 378592      ZWE    Africa     Zimbabwe  2024-02-09     266319.0        0.0
# 378593      ZWE    Africa     Zimbabwe  2024-02-10     266319.0        0.0
# 378594      ZWE    Africa     Zimbabwe  2024-02-11     266328.0        9.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 378590               4.429        5737.0         0.0                  0.0
# 378591               4.429        5737.0         0.0                  0.0
# 378592               4.429        5737.0         0.0                  0.0
# 378593               4.429        5737.0         0.0                  0.0
# 378594               1.286        5737.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 378590  ...          30.7                  36.791                         1.7
# 378591  ...          30.7                  36.791                         1.7
# 378592  ...          30.7                  36.791                         1.7
# 378593  ...          30.7                  36.791                         1.7
# 378594  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 378590            61.49                    0.571  16320539.0
# 378591            61.49                    0.571  16320539.0
# 378592            61.49                    0.571  16320539.0
# 378593            61.49                    0.571  16320539.0
# 378594            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 378590                                   NaN                          NaN
# 378591                                   NaN                          NaN
# 378592                                   NaN                          NaN
# 378593                                   NaN                          NaN
# 378594                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 378590               NaN                                      NaN
# 378591               NaN                                      NaN
# 378592               NaN                                      NaN
# 378593               NaN                                      NaN
# 378594               NaN                                      NaN
#
# [378595 rows x 67 columns]

# %%
df.describe(include = "object")
# Out:
#        iso_code continent location        date      tests_units
# count    378595    360495   378595      378595           106788
# unique      255         6      255        1517                4
# top         IND    Africa    India  2022-04-20  tests performed
# freq       1513     85444     1513         255            80099

# %%
df.head(10).style.background_gradient(cmap='Reds')
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3618: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3619: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax
_row2_col37, #T_27493_row2_col38, #T_27493_row2_col39, #T_27493_row2_col40, #T_27493_row2_col41, #T_27493_row2_col42, #T_27493_row2_col43, #T_27493_row2_col44, #T_27493_row2_col45, #T_27493_row2_col46, #T_27493_row2_col47, #T_27493_row2_col63, #T_27493_row2_col64, #T_27493_row2_col65, #T_27493_row2_col66, #T_27493_row3_col16, #T_27493_row3_col17, #T_27493_row3_col18, #T_27493_row3_col19, #T_27493_row3_col20, #T_27493_row3_col21, #T_27493_row3_col22, #T_27493_row3_col23, #T_27493_row3_col24, #T_27493_row3_col25, #T_27493_row3_col26, #T_27493_row3_col27, #T_27493_row3_col28, #T_27493_row3_col29, #T_27493_row3_col30, #T_27493_row3_col31, #T_27493_row3_col32, #T_27493_row3_col34, #T_27493_ro

# %% [markdown]
# ==========

# %% [markdown]
# ## EXPLORING WORLD DATA

# %% [markdown]
# ### Listinf all countries / regions in our data

# %%
df['location']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 378590       Zimbabwe
# 378591       Zimbabwe
# 378592       Zimbabwe
# 378593       Zimbabwe
# 378594       Zimbabwe
# Name: location, Length: 378595, dtype: object

# %%
df['location'].nunique()
# Out:
# 255

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'High income', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica',
#        'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low income', 'Lower middle income', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Micronesia (country)', 'Moldova', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Ireland', 'Northern Mariana Islands',
#        'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Reunion', 'Romania', 'Russia', 'Rwanda', 'Saint Barthelemy',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Martin (French part)', 'Saint Pierre and Miquelon',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wales', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %% [markdown]
# ### Selecting the 'World' data

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 378590      ZWE    Africa     Zimbabwe  2024-02-07     266319.0        0.0
# 378591      ZWE    Africa     Zimbabwe  2024-02-08     266319.0        0.0
# 378592      ZWE    Africa     Zimbabwe  2024-02-09     266319.0        0.0
# 378593      ZWE    Africa     Zimbabwe  2024-02-10     266319.0        0.0
# 378594      ZWE    Africa     Zimbabwe  2024-02-11     266328.0        9.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         0.0                  NaN
# 1                      NaN           NaN         0.0                  NaN
# 2                      NaN           NaN         0.0                  NaN
# 3                      NaN           NaN         0.0                  NaN
# 4                      NaN           NaN         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 378590               4.429        5737.0         0.0                  0.0
# 378591               4.429        5737.0         0.0                  0.0
# 378592               4.429        5737.0         0.0                  0.0
# 378593               4.429        5737.0         0.0                  0.0
# 378594               1.286        5737.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 378590  ...          30.7                  36.791                         1.7
# 378591  ...          30.7                  36.791                         1.7
# 378592  ...          30.7                  36.791                         1.7
# 378593  ...          30.7                  36.791                         1.7
# 378594  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 378590            61.49                    0.571  16320539.0
# 378591            61.49                    0.571  16320539.0
# 378592            61.49                    0.571  16320539.0
# 378593            61.49                    0.571  16320539.0
# 378594            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 378590                                   NaN                          NaN
# 378591                                   NaN                          NaN
# 378592                                   NaN                          NaN
# 378593                                   NaN                          NaN
# 378594                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 378590               NaN                                      NaN
# 378591               NaN                                      NaN
# 378592               NaN                                      NaN
# 378593               NaN                                      NaN
# 378594               NaN                                      NaN
#
# [378595 rows x 67 columns]

# %%
df_world = df[df.location == 'World']
df_world
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 372585  OWID_WRL       NaN    World  2020-01-05          2.0        2.0
# 372586  OWID_WRL       NaN    World  2020-01-06          2.0        0.0
# 372587  OWID_WRL       NaN    World  2020-01-07          2.0        0.0
# 372588  OWID_WRL       NaN    World  2020-01-08          2.0        0.0
# 372589  OWID_WRL       NaN    World  2020-01-09          2.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 374093  OWID_WRL       NaN    World  2024-02-21          NaN        NaN
# 374094  OWID_WRL       NaN    World  2024-02-22          NaN        NaN
# 374095  OWID_WRL       NaN    World  2024-02-23          NaN        NaN
# 374096  OWID_WRL       NaN    World  2024-02-24          NaN        NaN
# 374097  OWID_WRL       NaN    World  2024-02-25          NaN        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 372585                 NaN           3.0         3.0                  NaN
# 372586                 NaN           3.0         0.0                  NaN
# 372587                 NaN           3.0         0.0                  NaN
# 372588                 NaN           3.0         0.0                  NaN
# 372589                 NaN           3.0         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 374093                 NaN           NaN         NaN                  NaN
# 374094                 NaN           NaN         NaN                  NaN
# 374095                 NaN           NaN         NaN                  NaN
# 374096                 NaN           NaN         NaN                  NaN
# 374097                 NaN           NaN         NaN                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 372585  ...        34.635                   60.13                       2.705
# 372586  ...        34.635                   60.13                       2.705
# 372587  ...        34.635                   60.13                       2.705
# 372588  ...        34.635                   60.13                       2.705
# 372589  ...        34.635                   60.13                       2.705
# ...     ...           ...                     ...                         ...
# 374093  ...        34.635                   60.13                       2.705
# 374094  ...        34.635                   60.13                       2.705
# 374095  ...        34.635                   60.13                       2.705
# 374096  ...        34.635                   60.13                       2.705
# 374097  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 372585            72.58                    0.737  7.975105e+09
# 372586            72.58                    0.737  7.975105e+09
# 372587            72.58                    0.737  7.975105e+09
# 372588            72.58                    0.737  7.975105e+09
# 372589            72.58                    0.737  7.975105e+09
# ...                 ...                      ...           ...
# 374093            72.58                    0.737  7.975105e+09
# 374094            72.58                    0.737  7.975105e+09
# 374095            72.58                    0.737  7.975105e+09
# 374096            72.58                    0.737  7.975105e+09
# 374097            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 372585                                   NaN                          NaN
# 372586                                   NaN                          NaN
# 372587                                   NaN                          NaN
# 372588                                   NaN                          NaN
# 372589                                   NaN                          NaN
# ...                                      ...                          ...
# 374093                                   NaN                          NaN
# 374094                                   NaN                          NaN
# 374095                                   NaN                          NaN
# 374096                                   NaN                          NaN
# 374097                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 372585               NaN                                      NaN
# 372586               NaN                                      NaN
# 372587               NaN                                      NaN
# 372588               NaN                                      NaN
# 372589               NaN                                      NaN
# ...                  ...                                      ...
# 374093               NaN                                      NaN
# 374094               NaN                                      NaN
# 374095               NaN                                      NaN
# 374096               NaN                                      NaN
# 374097               NaN                                      NaN
#
# [1513 rows x 67 columns]

# %% [markdown]
# ### Finding the date of the maximum number of deaths all over the world

# %%
df_world['new_deaths'].max()# اكبر عدد كام
# Out:
# 103719.0

# %%
df_world[df_world['new_deaths'] == df_world['new_deaths'].max()]
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 372970  OWID_WRL       NaN    World  2021-01-24   98651492.0  4227124.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 372970          603874.857     2280872.0    103719.0              14817.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 372970  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 372970            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 372970                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 372970               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_world[df_world['new_deaths'] == df_world['new_deaths'].max()]['date']
# Out:
# 372970    2021-01-24
# Name: date, dtype: object

# %%
df_world['new_deaths'].idxmax()
# Out:
# 372970

# %%
df_world.loc[df_world['new_deaths'].idxmax()]['date']
# Out:
# '2021-01-24'

# %% [markdown]
# ### Finding the date of the minimum number of deaths all over the world

# %%
df_world[df_world['new_deaths'] == df_world['new_deaths'].min()]
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 372586  OWID_WRL       NaN    World  2020-01-06          2.0        0.0
# 372587  OWID_WRL       NaN    World  2020-01-07          2.0        0.0
# 372588  OWID_WRL       NaN    World  2020-01-08          2.0        0.0
# 372589  OWID_WRL       NaN    World  2020-01-09          2.0        0.0
# 372590  OWID_WRL       NaN    World  2020-01-10          2.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 374078  OWID_WRL       NaN    World  2024-02-06  774549276.0        0.0
# 374079  OWID_WRL       NaN    World  2024-02-07  774549276.0        0.0
# 374080  OWID_WRL       NaN    World  2024-02-08  774549276.0        0.0
# 374081  OWID_WRL       NaN    World  2024-02-09  774549276.0        0.0
# 374082  OWID_WRL       NaN    World  2024-02-10  774549276.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 372586                 NaN           3.0         0.0                  NaN
# 372587                 NaN           3.0         0.0                  NaN
# 372588                 NaN           3.0         0.0                  NaN
# 372589                 NaN           3.0         0.0                  NaN
# 372590               0.286           3.0         0.0                0.429
# ...                    ...           ...         ...                  ...
# 374078           13590.714     7030145.0         0.0               98.286
# 374079           13590.714     7030145.0         0.0               98.286
# 374080           13590.714     7030145.0         0.0               98.286
# 374081           13590.714     7030145.0         0.0               98.286
# 374082           13590.714     7030145.0         0.0               98.286
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 372586  ...        34.635                   60.13                       2.705
# 372587  ...        34.635                   60.13                       2.705
# 372588  ...        34.635                   60.13                       2.705
# 372589  ...        34.635                   60.13                       2.705
# 372590  ...        34.635                   60.13                       2.705
# ...     ...           ...                     ...                         ...
# 374078  ...        34.635                   60.13                       2.705
# 374079  ...        34.635                   60.13                       2.705
# 374080  ...        34.635                   60.13                       2.705
# 374081  ...        34.635                   60.13                       2.705
# 374082  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 372586            72.58                    0.737  7.975105e+09
# 372587            72.58                    0.737  7.975105e+09
# 372588            72.58                    0.737  7.975105e+09
# 372589            72.58                    0.737  7.975105e+09
# 372590            72.58                    0.737  7.975105e+09
# ...                 ...                      ...           ...
# 374078            72.58                    0.737  7.975105e+09
# 374079            72.58                    0.737  7.975105e+09
# 374080            72.58                    0.737  7.975105e+09
# 374081            72.58                    0.737  7.975105e+09
# 374082            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 372586                                   NaN                          NaN
# 372587                                   NaN                          NaN
# 372588                                   NaN                          NaN
# 372589                                   NaN                          NaN
# 372590                                   NaN                          NaN
# ...                                      ...                          ...
# 374078                                   NaN                          NaN
# 374079                                   NaN                          NaN
# 374080                                   NaN                          NaN
# 374081                                   NaN                          NaN
# 374082                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 372586               NaN                                      NaN
# 372587               NaN                                      NaN
# 372588               NaN                                      NaN
# 372589               NaN                                      NaN
# 372590               NaN                                      NaN
# ...                  ...                                      ...
# 374078               NaN                                      NaN
# 374079               NaN                                      NaN
# 374080               NaN                                      NaN
# 374081               NaN                                      NaN
# 374082               NaN                                      NaN
#
# [1284 rows x 67 columns]

# %%
df_world[df_world['new_deaths'] == df_world['new_deaths'].min()]['date']
# Out:
# 372586    2020-01-06
# 372587    2020-01-07
# 372588    2020-01-08
# 372589    2020-01-09
# 372590    2020-01-10
#              ...
# 374078    2024-02-06
# 374079    2024-02-07
# 374080    2024-02-08
# 374081    2024-02-09
# 374082    2024-02-10
# Name: date, Length: 1284, dtype: object

# %%
df_world['new_deaths'].idxmin()
# Out:
# 372586

# %%
df_world.loc   [df_world['new_deaths'].idxmin()] ['date']
# Out:
# '2020-01-06'

# %% [markdown]
# طريقه تانيه ???

# %%
df_world['new_deaths'].argmax()
# Out:
# 385

# %%
df_world.iloc[df_world['new_deaths'].argmax()] ['date']
# Out:
# '2021-01-24'

# %%
df_world.iloc[df_world['new_deaths'].argmin()] ['date']
# Out:
# '2020-01-06'

# %% [markdown]
# ### Creating a summary table for the most recent date all over the world

# %%
df_world
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 372585  OWID_WRL       NaN    World  2020-01-05          2.0        2.0
# 372586  OWID_WRL       NaN    World  2020-01-06          2.0        0.0
# 372587  OWID_WRL       NaN    World  2020-01-07          2.0        0.0
# 372588  OWID_WRL       NaN    World  2020-01-08          2.0        0.0
# 372589  OWID_WRL       NaN    World  2020-01-09          2.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 374093  OWID_WRL       NaN    World  2024-02-21          NaN        NaN
# 374094  OWID_WRL       NaN    World  2024-02-22          NaN        NaN
# 374095  OWID_WRL       NaN    World  2024-02-23          NaN        NaN
# 374096  OWID_WRL       NaN    World  2024-02-24          NaN        NaN
# 374097  OWID_WRL       NaN    World  2024-02-25          NaN        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 372585                 NaN           3.0         3.0                  NaN
# 372586                 NaN           3.0         0.0                  NaN
# 372587                 NaN           3.0         0.0                  NaN
# 372588                 NaN           3.0         0.0                  NaN
# 372589                 NaN           3.0         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 374093                 NaN           NaN         NaN                  NaN
# 374094                 NaN           NaN         NaN                  NaN
# 374095                 NaN           NaN         NaN                  NaN
# 374096                 NaN           NaN         NaN                  NaN
# 374097                 NaN           NaN         NaN                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 372585  ...        34.635                   60.13                       2.705
# 372586  ...        34.635                   60.13                       2.705
# 372587  ...        34.635                   60.13                       2.705
# 372588  ...        34.635                   60.13                       2.705
# 372589  ...        34.635                   60.13                       2.705
# ...     ...           ...                     ...                         ...
# 374093  ...        34.635                   60.13                       2.705
# 374094  ...        34.635                   60.13                       2.705
# 374095  ...        34.635                   60.13                       2.705
# 374096  ...        34.635                   60.13                       2.705
# 374097  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 372585            72.58                    0.737  7.975105e+09
# 372586            72.58                    0.737  7.975105e+09
# 372587            72.58                    0.737  7.975105e+09
# 372588            72.58                    0.737  7.975105e+09
# 372589            72.58                    0.737  7.975105e+09
# ...                 ...                      ...           ...
# 374093            72.58                    0.737  7.975105e+09
# 374094            72.58                    0.737  7.975105e+09
# 374095            72.58                    0.737  7.975105e+09
# 374096            72.58                    0.737  7.975105e+09
# 374097            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 372585                                   NaN                          NaN
# 372586                                   NaN                          NaN
# 372587                                   NaN                          NaN
# 372588                                   NaN                          NaN
# 372589                                   NaN                          NaN
# ...                                      ...                          ...
# 374093                                   NaN                          NaN
# 374094                                   NaN                          NaN
# 374095                                   NaN                          NaN
# 374096                                   NaN                          NaN
# 374097                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 372585               NaN                                      NaN
# 372586               NaN                                      NaN
# 372587               NaN                                      NaN
# 372588               NaN                                      NaN
# 372589               NaN                                      NaN
# ...                  ...                                      ...
# 374093               NaN                                      NaN
# 374094               NaN                                      NaN
# 374095               NaN                                      NaN
# 374096               NaN                                      NaN
# 374097               NaN                                      NaN
#
# [1513 rows x 67 columns]

# %%
df_world ['date'].sort_values(ascending = False) .head(4)
# Out:
# 374066    2024-01-25
# 374065    2024-01-24
# 374064    2024-01-23
# 374063    2024-01-22
# Name: date, dtype: object

# %%
df_world .sort_values(['date'], ascending = False).head(1)
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 374097  OWID_WRL       NaN    World  2024-02-25          NaN        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 374097                 NaN           NaN         NaN                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 374097  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 374097            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 374097                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 374097               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
#df_world = df_world.iloc[:-2 , :]
df_world = df_world.iloc[:-20]

df_world
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 372585  OWID_WRL       NaN    World  2020-01-05          2.0        2.0
# 372586  OWID_WRL       NaN    World  2020-01-06          2.0        0.0
# 372587  OWID_WRL       NaN    World  2020-01-07          2.0        0.0
# 372588  OWID_WRL       NaN    World  2020-01-08          2.0        0.0
# 372589  OWID_WRL       NaN    World  2020-01-09          2.0        0.0
# ...          ...       ...      ...         ...          ...        ...
# 374062  OWID_WRL       NaN    World  2024-01-21  774344463.0   130540.0
# 374063  OWID_WRL       NaN    World  2024-01-22  774344463.0        0.0
# 374064  OWID_WRL       NaN    World  2024-01-23  774344463.0        0.0
# 374065  OWID_WRL       NaN    World  2024-01-24  774344463.0        0.0
# 374066  OWID_WRL       NaN    World  2024-01-25  774344463.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 372585                 NaN           3.0         3.0                  NaN
# 372586                 NaN           3.0         0.0                  NaN
# 372587                 NaN           3.0         0.0                  NaN
# 372588                 NaN           3.0         0.0                  NaN
# 372589                 NaN           3.0         0.0                  NaN
# ...                    ...           ...         ...                  ...
# 374062           18648.571     7025785.0      1048.0              149.714
# 374063           18648.571     7025785.0         0.0              149.714
# 374064           18648.571     7025785.0         0.0              149.714
# 374065           18648.571     7025785.0         0.0              149.714
# 374066           18648.571     7025785.0         0.0              149.714
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 372585  ...        34.635                   60.13                       2.705
# 372586  ...        34.635                   60.13                       2.705
# 372587  ...        34.635                   60.13                       2.705
# 372588  ...        34.635                   60.13                       2.705
# 372589  ...        34.635                   60.13                       2.705
# ...     ...           ...                     ...                         ...
# 374062  ...        34.635                   60.13                       2.705
# 374063  ...        34.635                   60.13                       2.705
# 374064  ...        34.635                   60.13                       2.705
# 374065  ...        34.635                   60.13                       2.705
# 374066  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 372585            72.58                    0.737  7.975105e+09
# 372586            72.58                    0.737  7.975105e+09
# 372587            72.58                    0.737  7.975105e+09
# 372588            72.58                    0.737  7.975105e+09
# 372589            72.58                    0.737  7.975105e+09
# ...                 ...                      ...           ...
# 374062            72.58                    0.737  7.975105e+09
# 374063            72.58                    0.737  7.975105e+09
# 374064            72.58                    0.737  7.975105e+09
# 374065            72.58                    0.737  7.975105e+09
# 374066            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 372585                                   NaN                          NaN
# 372586                                   NaN                          NaN
# 372587                                   NaN                          NaN
# 372588                                   NaN                          NaN
# 372589                                   NaN                          NaN
# ...                                      ...                          ...
# 374062                                   NaN                          NaN
# 374063                                   NaN                          NaN
# 374064                                   NaN                          NaN
# 374065                                   NaN                          NaN
# 374066                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 372585               NaN                                      NaN
# 372586               NaN                                      NaN
# 372587               NaN                                      NaN
# 372588               NaN                                      NaN
# 372589               NaN                                      NaN
# ...                  ...                                      ...
# 374062               NaN                                      NaN
# 374063               NaN                                      NaN
# 374064               NaN                                      NaN
# 374065               NaN                                      NaN
# 374066               NaN                                      NaN
#
# [1482 rows x 67 columns]

# %%
df_world.sort_values(['date'], ascending = False).head(1)
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 374066  OWID_WRL       NaN    World  2024-01-25  774344463.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 374066           18648.571     7025785.0         0.0              149.714
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 374066  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 374066            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 374066                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 374066               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_world_recent = df_world[df_world['date'] == df_world.date.max()]
df_world_recent
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 374066  OWID_WRL       NaN    World  2024-01-25  774344463.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 374066           18648.571     7025785.0         0.0              149.714
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 374066  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 374066            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 374066                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 374066               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_world_recent[["date","total_cases","new_cases","new_deaths","total_deaths"]]
# Out:
#               date  total_cases  new_cases  new_deaths  total_deaths
# 374066  2024-01-25  774344463.0        0.0         0.0     7025785.0

# %%
 df_world_recent.groupby("date")[["total_cases","new_cases","new_deaths","total_deaths"]].sum()
# Out:
#             total_cases  new_cases  new_deaths  total_deaths
# date
# 2024-01-25  774344463.0        0.0         0.0     7025785.0

# %% [markdown]
# ### Calculating the percentage of confirmed cases regarding the world population

# %%
df_world['population'].unique()
# Out:
# array([7.97510502e+09])

# %%
#df_world['total_cases']

# %%
df_world['total_cases'].max()
# Out:
# 774344463.0

# %%
df_world_ratio = df_world['total_cases'].max() / df_world['population'].max()
df_world_ratio
# Out:
# 0.0970952057270362

# %% [markdown]
# ==========

# %% [markdown]
# ## VISUALLIZING WORLD DATA

# %% [markdown]
# ### Confirmed cases (Total Cases) all over the world

# %%
df_world_over_time = df_world.groupby(["date"])[["total_cases","new_cases","total_deaths","new_deaths"]].sum()
df_world_over_time
# Out:
#             total_cases  new_cases  total_deaths  new_deaths
# date
# 2020-01-05          2.0        2.0           3.0         3.0
# 2020-01-06          2.0        0.0           3.0         0.0
# 2020-01-07          2.0        0.0           3.0         0.0
# 2020-01-08          2.0        0.0           3.0         0.0
# 2020-01-09          2.0        0.0           3.0         0.0
# ...                 ...        ...           ...         ...
# 2024-01-21  774344463.0   130540.0     7025785.0      1048.0
# 2024-01-22  774344463.0        0.0     7025785.0         0.0
# 2024-01-23  774344463.0        0.0     7025785.0         0.0
# 2024-01-24  774344463.0        0.0     7025785.0         0.0
# 2024-01-25  774344463.0        0.0     7025785.0         0.0
#
# [1482 rows x 4 columns]

# %%
df_world_over_time = df_world.groupby(["date"])[["total_cases","new_cases","total_deaths","new_deaths"]].sum().reset_index()
df_world_over_time
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 0     2020-01-05          2.0        2.0           3.0         3.0
# 1     2020-01-06          2.0        0.0           3.0         0.0
# 2     2020-01-07          2.0        0.0           3.0         0.0
# 3     2020-01-08          2.0        0.0           3.0         0.0
# 4     2020-01-09          2.0        0.0           3.0         0.0
# ...          ...          ...        ...           ...         ...
# 1477  2024-01-21  774344463.0   130540.0     7025785.0      1048.0
# 1478  2024-01-22  774344463.0        0.0     7025785.0         0.0
# 1479  2024-01-23  774344463.0        0.0     7025785.0         0.0
# 1480  2024-01-24  774344463.0        0.0     7025785.0         0.0
# 1481  2024-01-25  774344463.0        0.0     7025785.0         0.0
#
# [1482 rows x 5 columns]

# %%
# Using line-plot

plt.figure(figsize=(20,10))  

#plt.plot(df_world_over_time['date'], df_world_over_time['total_cases'])

plt.plot(df_world_over_time.index, df_world_over_time['total_cases'])


plt.title('Evolution of Confirmed Covid-19 cases over time in the word', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Confirmed cases', fontsize=1)
plt.show()

# %%
# Using line-plot
plt.figure(figsize=(20,10))
plt.plot(df_world_over_time['date'], df_world_over_time['total_deaths'])

#plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'])

plt.title('Evolution of Confirmed Covid-19 cases over time in the word', fontsize=16)
plt.xlabel('year', fontsize=16)
plt.ylabel('Confirmed cases', fontsize=16)
plt.show()

# %%
df_world_over_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482 entries, 0 to 1481
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1482 non-null   object
#  1   total_cases   1482 non-null   float64
#  2   new_cases     1482 non-null   float64
#  3   total_deaths  1482 non-null   float64
#  4   new_deaths    1482 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 58.0+ KB

# %%
df_world_over_time['date'] = pd.     to_datetime     (df_world_over_time['date'])

# %%
df_world_over_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482 entries, 0 to 1481
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1482 non-null   datetime64[ns]
#  1   total_cases   1482 non-null   float64
#  2   new_cases     1482 non-null   float64
#  3   total_deaths  1482 non-null   float64
#  4   new_deaths    1482 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 58.0 KB

# %%
##. Time series analysis
#https://youtu.be/iLY2Q43ES1o?si=T9sB_d87zNlt9YGY
#https://youtu.be/agXpmieuYS4?si=OBcGLqKwkTFBV0bn

# %% [markdown]
# ### Total deaths cases evolution over time

# %%
# Using line-plot
plt.figure(figsize=(20,10))

#plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'])
plt.plot(df_world_over_time['date'], df_world_over_time['total_cases'])

plt.title('Evolution of Covid-19 Deaths cases over time in the world', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('Number of Deaths', fontsize=16)
# Out:
# Text(0, 0.5, 'Number of Deaths')

# %% [markdown]
# ### New cases all over the world

# %%
# Using line-plot
plt.figure(figsize=(12,5))
plt.bar(df_world_over_time.index, df_world_over_time['new_cases'])
#plt.plot(df_world_over_time['date'], df_world_over_time['total_cases'])

plt.title('Evolution of Covid-19 New Cases over time in the world', fontsize=16)
plt.xlabel('Days', fontsize=16)
plt.ylabel('New Cases', fontsize=16)
# Out:
# Text(0, 0.5, 'New Cases')

# %% [markdown]
# ### Putting it all together

# %%
# Using line-plot
plt.figure(figsize=(20,10))
#plt.plot(df_world_over_time.index, df_world_over_time['total_cases'], label='Confirmed')
plt.plot(df_world_over_time.index, df_world_over_time['total_deaths'], label='Total Deaths')
plt.plot(df_world_over_time.index, df_world_over_time['new_cases'], label='new_cases')
plt.plot(df_world_over_time.index, df_world_over_time['new_deaths'], label='New Deaths')
plt.legend(loc=0)
plt.show()

# %% [markdown]
# ==========

# %% [markdown]
# ## EXPLORING EGYPT DATA

# %% [markdown]
# ### Let's first get 'Egypt' data

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'High income', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica',
#        'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low income', 'Lower middle income', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Micronesia (country)', 'Moldova', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Ireland', 'Northern Mariana Islands',
#        'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Reunion', 'Romania', 'Russia', 'Rwanda', 'Saint Barthelemy',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Martin (French part)', 'Saint Pierre and Miquelon',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wales', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df_egypt = df  [df['location'] == 'Egypt']
df_egypt
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 93007      EGY    Africa    Egypt  2020-01-05          NaN        0.0
# 93008      EGY    Africa    Egypt  2020-01-06          NaN        0.0
# 93009      EGY    Africa    Egypt  2020-01-07          NaN        0.0
# 93010      EGY    Africa    Egypt  2020-01-08          NaN        0.0
# 93011      EGY    Africa    Egypt  2020-01-09          NaN        0.0
# ...        ...       ...      ...         ...          ...        ...
# 94501      EGY    Africa    Egypt  2024-02-07     516023.0        0.0
# 94502      EGY    Africa    Egypt  2024-02-08     516023.0        0.0
# 94503      EGY    Africa    Egypt  2024-02-09     516023.0        0.0
# 94504      EGY    Africa    Egypt  2024-02-10     516023.0        0.0
# 94505      EGY    Africa    Egypt  2024-02-11     516023.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 93007                 NaN           NaN         0.0                  NaN  ...
# 93008                 NaN           NaN         0.0                  NaN  ...
# 93009                 NaN           NaN         0.0                  NaN  ...
# 93010                 NaN           NaN         0.0                  NaN  ...
# 93011                 NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 94501                 0.0       24830.0         0.0                  0.0  ...
# 94502                 0.0       24830.0         0.0                  0.0  ...
# 94503                 0.0       24830.0         0.0                  0.0  ...
# 94504                 0.0       24830.0         0.0                  0.0  ...
# 94505                 0.0       24830.0         0.0                  0.0  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 93007          50.1                  89.827                         1.6
# 93008          50.1                  89.827                         1.6
# 93009          50.1                  89.827                         1.6
# 93010          50.1                  89.827                         1.6
# 93011          50.1                  89.827                         1.6
# ...             ...                     ...                         ...
# 94501          50.1                  89.827                         1.6
# 94502          50.1                  89.827                         1.6
# 94503          50.1                  89.827                         1.6
# 94504          50.1                  89.827                         1.6
# 94505          50.1                  89.827                         1.6
#
#        life_expectancy  human_development_index   population  \
# 93007            71.99                    0.707  110990096.0
# 93008            71.99                    0.707  110990096.0
# 93009            71.99                    0.707  110990096.0
# 93010            71.99                    0.707  110990096.0
# 93011            71.99                    0.707  110990096.0
# ...                ...                      ...          ...
# 94501            71.99                    0.707  110990096.0
# 94502            71.99                    0.707  110990096.0
# 94503            71.99                    0.707  110990096.0
# 94504            71.99                    0.707  110990096.0
# 94505            71.99                    0.707  110990096.0
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 93007                                   NaN                          NaN
# 93008                                   NaN                          NaN
# 93009                                   NaN                          NaN
# 93010                                   NaN                          NaN
# 93011                                   NaN                          NaN
# ...                                     ...                          ...
# 94501                                   NaN                          NaN
# 94502                                   NaN                          NaN
# 94503                                   NaN                          NaN
# 94504                                   NaN                          NaN
# 94505                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 93007               NaN                                      NaN
# 93008               NaN                                      NaN
# 93009               NaN                                      NaN
# 93010               NaN                                      NaN
# 93011               NaN                                      NaN
# ...                 ...                                      ...
# 94501               NaN                                      NaN
# 94502               NaN                                      NaN
# 94503               NaN                                      NaN
# 94504               NaN                                      NaN
# 94505               NaN                                      NaN
#
# [1499 rows x 67 columns]

# %%
#df_egypt.reset_index()

#df_egypt.reset_index(drop = True)

df_egypt.reset_index(drop = True , inplace = True)


df_egypt
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 0         EGY    Africa    Egypt  2020-01-05          NaN        0.0
# 1         EGY    Africa    Egypt  2020-01-06          NaN        0.0
# 2         EGY    Africa    Egypt  2020-01-07          NaN        0.0
# 3         EGY    Africa    Egypt  2020-01-08          NaN        0.0
# 4         EGY    Africa    Egypt  2020-01-09          NaN        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1494      EGY    Africa    Egypt  2024-02-07     516023.0        0.0
# 1495      EGY    Africa    Egypt  2024-02-08     516023.0        0.0
# 1496      EGY    Africa    Egypt  2024-02-09     516023.0        0.0
# 1497      EGY    Africa    Egypt  2024-02-10     516023.0        0.0
# 1498      EGY    Africa    Egypt  2024-02-11     516023.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                    NaN           NaN         0.0                  NaN  ...
# 1                    NaN           NaN         0.0                  NaN  ...
# 2                    NaN           NaN         0.0                  NaN  ...
# 3                    NaN           NaN         0.0                  NaN  ...
# 4                    NaN           NaN         0.0                  NaN  ...
# ...                  ...           ...         ...                  ...  ...
# 1494                 0.0       24830.0         0.0                  0.0  ...
# 1495                 0.0       24830.0         0.0                  0.0  ...
# 1496                 0.0       24830.0         0.0                  0.0  ...
# 1497                 0.0       24830.0         0.0                  0.0  ...
# 1498                 0.0       24830.0         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0             50.1                  89.827                         1.6
# 1             50.1                  89.827                         1.6
# 2             50.1                  89.827                         1.6
# 3             50.1                  89.827                         1.6
# 4             50.1                  89.827                         1.6
# ...            ...                     ...                         ...
# 1494          50.1                  89.827                         1.6
# 1495          50.1                  89.827                         1.6
# 1496          50.1                  89.827                         1.6
# 1497          50.1                  89.827                         1.6
# 1498          50.1                  89.827                         1.6
#
#       life_expectancy  human_development_index   population  \
# 0               71.99                    0.707  110990096.0
# 1               71.99                    0.707  110990096.0
# 2               71.99                    0.707  110990096.0
# 3               71.99                    0.707  110990096.0
# 4               71.99                    0.707  110990096.0
# ...               ...                      ...          ...
# 1494            71.99                    0.707  110990096.0
# 1495            71.99                    0.707  110990096.0
# 1496            71.99                    0.707  110990096.0
# 1497            71.99                    0.707  110990096.0
# 1498            71.99                    0.707  110990096.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 1494                                   NaN                          NaN
# 1495                                   NaN                          NaN
# 1496                                   NaN                          NaN
# 1497                                   NaN                          NaN
# 1498                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 1494               NaN                                      NaN
# 1495               NaN                                      NaN
# 1496               NaN                                      NaN
# 1497               NaN                                      NaN
# 1498               NaN                                      NaN
#
# [1499 rows x 67 columns]

# %%
df_egypt.head()
# Out:
#   iso_code continent location        date  total_cases  new_cases  \
# 0      EGY    Africa    Egypt  2020-01-05          NaN        0.0
# 1      EGY    Africa    Egypt  2020-01-06          NaN        0.0
# 2      EGY    Africa    Egypt  2020-01-07          NaN        0.0
# 3      EGY    Africa    Egypt  2020-01-08          NaN        0.0
# 4      EGY    Africa    Egypt  2020-01-09          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0          50.1                  89.827                         1.6
# 1          50.1                  89.827                         1.6
# 2          50.1                  89.827                         1.6
# 3          50.1                  89.827                         1.6
# 4          50.1                  89.827                         1.6
#
#    life_expectancy  human_development_index   population  \
# 0            71.99                    0.707  110990096.0
# 1            71.99                    0.707  110990096.0
# 2            71.99                    0.707  110990096.0
# 3            71.99                    0.707  110990096.0
# 4            71.99                    0.707  110990096.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df_egypt.head(10).style.background_gradient(cmap='Reds')
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3618: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3619: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_1f2a3_row0_col4, #T_1f2a3_row0_col7, #T_1f2a3_row0_col10, #T_1f2a3_row0_col13, #T_1f2a3_row0_col16, #T_1f2a3_row0_col17, #T_1f2a3_row0_col18, #T_1f2a3_row0_col19, #T_1f2a3_row0_col20, #T_1f2a3_row0_col21, #T_1f2a3_row0_col22, #T_1f2a3_row0_col23, #T_1f2a3_row0_col24, #T_1f2a3_row0_col25, #T_1f2a3_row0_col26, #T_1f2a3_row0_col27, #T_1f2a3_row0_col28, #T_1f2a3_row0_col29, #T_1f2a3_row0_col30, #T_1f2a3_row0_col31, #T_1f2a3_row0_col32, #T_1f2a3_row0_col34, #T_1f2a3_row0_col35, #T_1f2a3_row0_col36, #T_1f2a3_row0_col37, #T_1f2a3_row0_col38, #T_1f2a3_row0_col39, #T_1f2a3_row0_col40, #T_1f2a3_row0_col41, #T_1f2a3_row0_col42, #T_1f2a3_row0_col43, #T_1f2a3_row0_col44, #T_1f2a3_row0_col45, #T_1f2a3_row0_col46, #T_1f2a3_row0_col63, #T_1f2a3_row0_col64, #T_1f2a3_row0_col65, #T_1f2a3_row0_col66, #T_1f2a3_row1_col4, #T_1f2a3_row1_col7, #T_1f2a3_row1_col10, #T_1f2a3_row1_col13, #T_1f2a3_row1_col16, #T_1f2a3_row1_col17, #T_1f2a3_row1_col18, #T_1f2a3_row1_col19, #T_1f2a3_row1_col20, #T_1f2a3_row1_col21, #T_1f2a3_row1_col22, #T_1f2a3_row1_col23, #T_1f2a3_row1_col24, #T_1f2a3_row1_col25, #T_1f2a3_row1_col26, #T_1f2a3_row1_col27, #T_1f2a3_row1_col28, #T_1f2a3_row1_col29, #T_1f2a3_row1_col30, #T_1f2a3_row1_col31, #T_1f2a3_row1_col32, #T_1f2a3_row1_col34, #T_1f2a3_row1_col35, #T_1f2a3_row1_col36, #T_1f2a3_row1_col37, #T_1f2a3_row1_col38, #T_1f2a3_row1_col39, #T_1f2a3_row1_col40, #T_1f2a3_row1_col41, #T_1f2a3_row1_col42, #T_1f2a3_row1_col43, #T_1f2a3_row1_col44, #T_1f2a3_row1_col45, #T_1f2a3_row1_col46, #T_1f2a3_row1_col63, #T_1f2a3_row1_col64, #T_1f2a3_row1_col65, #T_1f2a3_row1_col66, #T_1f2a3_row2_col4, #T_1f2a3_row2_col7, #T_1f2a3_row2_col10, #T_1f2a3_row2_col13, #T_1f2a3_row2_col16, #T_1f2a3_row2_col17, #T_1f2a3_row2_col18, #T_1f2a3_row2_col19, #T_1f2a3_row2_col20, #T_1f2a3_row2_col21, #T_1f2a3_row2_col22, #T_1f2a3_row2_col23, #T_1f2a3_row2_col24, #T_1f2a3_row2_col25, #T_1f2a3_row2_col26, #T_1f2a3_row2_col27, #T_1f2a3_row2_col28, #T_1f2a3_row2_col29, #T_1f2a3_row2_col30, #T_1f2a3_row2_col31, #T_1f2a3_row2_col32, #T_1f2a3_row2_col34, #T_1f2a3_row2_col35, #T_1f2a3_row2_col36, #T_1f2a3_row2_col37, #T_1f2a3_row2_col38, #T_1f2a3_row2_col39, #T_1f2a3_row2_col40, #T_1f2a3_row2_col41, #T_1f2a3_row2_col42, #T_1f2a3_row2_col43, #T_1f2a3_row2_col44, #T_1f2a3_row2_col45, #T_1f2a3_row2_col46, #T_1f2a3_row2_col63, #T_1f2a3_row2_col64, #T_1f2a3_row2_col65, #T_1f2a3_row2_col66, #T_1f2a3_row3_col4, #T_1f2a3_row3_col7, #T_1f2a3_row3_col10, #T_1f2a3_row3_col13, #T_1f2a3_row3_col16, #T_1f2a3_row3_col17, #T_1f2a3_row3_col18, #T_1f2a3_row3_col19, #T_1f2a3_row3_col20, #T_1f2a3_row3_col21, #T_1f2a3_row3_col22, #T_1f2a3_row3_col23, #T_1f2a3_row3_col24, #T_1f2a3_row3_col25, #T_1f2a3_row3_col26, #T_1f2a3_row3_col27, #T_1f2a3_row3_col28, #T_1f2a3_row3_col29, #T_1f2a3_row3_col30, #T_1f2a3_row3_col31, #T_1f2a3_row3_col32, #T_1f2a3_row3_col34, #T_1f2a3_row3_col35, #T_1f2a3_row3_col36, #T_1f2a3_row3_col37, #T_1f2a3_row3_col38, #T_1f2a3_row3_col39, #T_1f2a3_row3_col40, #T_1f2a3_row3_col41, #T_1f2a3_row3_col42, #T_1f2a3_row3_col43, #T_1f2a3_row3_col44, #T_1f2a3_row3_col45, #T_1f2a3_row3_col46, #T_1f2a3_row3_col63, #T_1f2a3_row3_col64, #T_1f2a3_row3_col65, #T_1f2a3_row3_col66, #T_1f2a3_row4_col4, #T_1f2a3_row4_col7, #T_1f2a3_row4_col10, #T_1f2a3_row4_col13, #T_1f2a3_row4_col16, #T_1f2a3_row4_col17, #T_1f2a3_row4_col18, #T_1f2a3_row4_col19, #T_1f2a3_row4_col20, #T_1f2a3_row4_col21, #T_1f2a3_row4_col22, #T_1f2a3_row4_col23, #T_1f2a3_row4_col24, #T_1f2a3_row4_col25, #T_1f2a3_row4_col26, #T_1f2a3_row4_col27, #T_1f2a3_row4_col28, #T_1f2a3_row4_col29, #T_1f2a3_row4_col30, #T_1f2a3_row4_col31, #T_1f2a3_row4_col32, #T_1f2a3_row4_col34, #T_1f2a3_row4_col35, #T_1f2a3_row4_col36, #T_1f2a3_row4_col37, #T_1f2a3_row4_col38, #T_1f2a3_row4_col39, #T_1f2a3_row4_col40, #T_1f2a3_row4_col41, #T_1f2a3_row4_col42, #T_1f2a3_row4_col43, #T_1f2a3_row4_col44, #T_1f2a3_row4_col45, #T_1f2a3_row4_col46, #T_1f2a3_row4_col63, #T_1f2a3_row4_col64, #T_1f2a3_row4_col65, #T_1f2a3_row4_col66, #T_1f2a3_row5_col4,  ...
#   background-co

# %%
df_egypt.tail()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1494      EGY    Africa    Egypt  2024-02-07     516023.0        0.0
# 1495      EGY    Africa    Egypt  2024-02-08     516023.0        0.0
# 1496      EGY    Africa    Egypt  2024-02-09     516023.0        0.0
# 1497      EGY    Africa    Egypt  2024-02-10     516023.0        0.0
# 1498      EGY    Africa    Egypt  2024-02-11     516023.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1494                 0.0       24830.0         0.0                  0.0  ...
# 1495                 0.0       24830.0         0.0                  0.0  ...
# 1496                 0.0       24830.0         0.0                  0.0  ...
# 1497                 0.0       24830.0         0.0                  0.0  ...
# 1498                 0.0       24830.0         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1494          50.1                  89.827                         1.6
# 1495          50.1                  89.827                         1.6
# 1496          50.1                  89.827                         1.6
# 1497          50.1                  89.827                         1.6
# 1498          50.1                  89.827                         1.6
#
#       life_expectancy  human_development_index   population  \
# 1494            71.99                    0.707  110990096.0
# 1495            71.99                    0.707  110990096.0
# 1496            71.99                    0.707  110990096.0
# 1497            71.99                    0.707  110990096.0
# 1498            71.99                    0.707  110990096.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1494                                   NaN                          NaN
# 1495                                   NaN                          NaN
# 1496                                   NaN                          NaN
# 1497                                   NaN                          NaN
# 1498                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1494               NaN                                      NaN
# 1495               NaN                                      NaN
# 1496               NaN                                      NaN
# 1497               NaN                                      NaN
# 1498               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df_egypt.head(10).style.background_gradient(cmap='Reds')
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3618: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3619: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_4f82c_row0_col4, #T_4f82c_row0_col7, #T_4f82c_row0_col10, #T_4f82c_row0_col13, #T_4f82c_row0_col16, #T_4f82c_row0_col17, #T_4f82c_row0_col18, #T_4f82c_row0_col19, #T_4f82c_row0_col20, #T_4f82c_row0_col21, #T_4f82c_row0_col22, #T_4f82c_row0_col23, #T_4f82c_row0_col24, #T_4f82c_row0_col25, #T_4f82c_row0_col26, #T_4f82c_row0_col27, #T_4f82c_row0_col28, #T_4f82c_row0_col29, #T_4f82c_row0_col30, #T_4f82c_row0_col31, #T_4f82c_row0_col32, #T_4f82c_row0_col34, #T_4f82c_row0_col35, #T_4f82c_row0_col36, #T_4f82c_row0_col37, #T_4f82c_row0_col38, #T_4f82c_row0_col39, #T_4f82c_row0_col40, #T_4f82c_row0_col41, #T_4f82c_row0_col42, #T_4f82c_row0_col43, #T_4f82c_row0_col44, #T_4f82c_row0_col45, #T_4f82c_row0_col46, #T_4f82c_row0_col63, #T_4f82c_row0_col64, #T_4f82c_row0_col65, #T_4f82c_row0_col66, #T_4f82c_row1_col4, #T_4f82c_row1_col7, #T_4f82c_row1_col10, #T_4f82c_row1_col13, #T_4f82c_row1_col16, #T_4f82c_row1_col17, #T_4f82c_row1_col18, #T_4f82c_row1_col19, #T_4f82c_row1_col20, #T_4f82c_row1_col21, #T_4f82c_row1_col22, #T_4f82c_row1_col23, #T_4f82c_
col21, #T_4f82c_row4_col22, #T_4f82c_row4_col23, #T_4f82c_row4_col24, #T_4f82c_row4_col25, #T_4f82c_row4_col26, #T_4f82c_row4_col27, #T_4f82c_row4_col28, #T_4f82c_row4_col29, #T_4f82c_row4_col30, #T_4f82c_row4_col31, #T_4f82c_row4_col32, #T_4f82c_row4_col34, #T_4f82c_row4_col35, #T_4f82c_row4_col36, #T_4f82c_row4_col37, #T_4f82c_row4_col38, #T_4f82c_row4_col39, #T_4f82c_row4_col40, #T_4f82c_row4_col41, #T_4f82c_row4_col42, #T_4f82c_row4_col43, #T_4f82c_row4_col44, #T_4f82c_row4_col45, #T_4f82c_row4_col46, #T_4f82c_row4_col63, #T_4f82c_row4_col64, #T_4f82c_row4_col65, #T_4f82c_row4_col66, #T_4f82c_row5_col4,  ...
#   background-co

# %%
df_egypt.sample(6)
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 522       EGY    Africa    Egypt  2021-06-10     267171.0        0.0
# 599       EGY    Africa    Egypt  2021-08-26     286168.0        0.0
# 369       EGY    Africa    Egypt  2021-01-08     140878.0        0.0
# 90        EGY    Africa    Egypt  2020-04-04        576.0        0.0
# 905       EGY    Africa    Egypt  2022-06-28     514088.0        0.0
# 1211      EGY    Africa    Egypt  2023-04-30     516023.0       27.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 522              930.286       15309.0         0.0               44.000  ...
# 599              130.143       16663.0         0.0                6.857  ...
# 369             1366.143        7741.0         0.0               55.571  ...
# 90                40.286          36.0         0.0                3.714  ...
# 905                5.857       24723.0         0.0                0.143  ...
# 1211               3.857       24830.0         2.0                0.286  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 522           50.1                  89.827                         1.6
# 599           50.1                  89.827                         1.6
# 369           50.1                  89.827                         1.6
# 90            50.1                  89.827                         1.6
# 905           50.1                  89.827                         1.6
# 1211          50.1                  89.827                         1.6
#
#       life_expectancy  human_development_index   population  \
# 522             71.99                    0.707  110990096.0
# 599             71.99                    0.707  110990096.0
# 369             71.99                    0.707  110990096.0
# 90              71.99                    0.707  110990096.0
# 905             71.99                    0.707  110990096.0
# 1211            71.99                    0.707  110990096.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 522                                    NaN                          NaN
# 599                                    NaN                          NaN
# 369                                    NaN                          NaN
# 90                                     NaN                          NaN
# 905                                    NaN                          NaN
# 1211                             335928.25                        17.91
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 522                NaN                                      NaN
# 599                NaN                                      NaN
# 369                NaN                                      NaN
# 90                 NaN                                      NaN
# 905                NaN                                      NaN
# 1211              8.38                                2980.2908
#
# [6 rows x 67 columns]

# %%
df_egypt.sample(6).style.background_gradient(cmap='Reds')
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3618: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Applications/anaconda3/lib/python3.11/site-packages/pandas/io/formats/style.py:3619: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax
a_row1_col41, #T_9925a_row1_col42, #T_9925a_row1_col43, #T_9925a_row1_col44, #T_9925a_row1_col45, #T_9925a_row1_col46, #T_9925a_row1_col47, #T_9925a_row2_col17, #T_9925a_row2_col18, #T_9925a_row2_col19, #T_9925a_row2_col20, #T_9925a_row2_col21, #T_9925a_row2_col22, #T_9925a_row2_col23, #T_9925a_row2_col24, #T_9925a_row2_col25, #T_9925a_row2_col26, #T_9925a_row2_col27, #T_9925a_row2_col28, #T_9925a_row2_col34, #T_9925a_row2_col35, #T_9925a_row2_col36, #T_9925a_row2_col37, #T_9925a_row2_col38, #T_9925a_row2_col40, #T_9925a_row2_col41, #T_9925a_row2_col42, #T_9925a_row2_col43, #T_9925a_row3_col17, #T_9925a_row3_col18, #T_9925a_row3_col19, #T_9925a_row3_col20, #T_9925a_row3_col21, #T_9925a_row3_col22, #T_9925a_row3_col23, #T_9925a_row3_col24, #T_9925a_row3_col25, #T_9925a_row3_col26, #T_9925a_row3_col27, #T_9925a_row3_col28, #T_9925a_row3_col34, #T_9925a_row3_col35, #T_9925a_row3_col36, #T_9925a_row3_col37, #T_9925a_row3_col38, #T_9925a_row3_col40, #T_9925a_row3_col41, #T_9925a_row3_col42, #T_9925a_row3_col43, #T_9925a_row4_col17, #T_9925a_row4_col18, #T_9925a_row4_col19, #T_9925a_row4_col20, #T_9925a_row4_col21, #T_9925a_row4_col22, #T_9925a_row4_col23, #T_9925a_row4_col24, #T_9925a_row4_col25, #T_9925a_row4_col26, #T_9925a_row4_col27, #T_9925a_row4_col28, #T_9925a_row4_col34, #T_9925a_row4_col35, #T_9925a_row4_col36, #T_9925a_row4_col37, #T_9925a_row4_col38, #T_9925a_row4_col39, #T_9925a_row4_col40, #T_9925a_row4_col41, #T_9925a_row4_col42, #T_9925a_row4_col43, #T_9925a_row4_col44, #T_9925a_row4_col45, #T_9925a_row4_col46, #T_9925a_row5_col16, #T_9925a_row5_col17, #T_9925a_row5_col18, #T_9925a_row5_col19, #T_9925a_row5_col20, #T_9925a_row5_col21, #T_9925a_row5_col22, #T_9925a_row5_col23, #T_9925a_row5_col24, #T_9925a_row5_col25, #T_9925a_row5_col26, #T_9925a_row5_col27, #T_9925a_row5_col28, #T_9925a_row5_col34, #T_9925a_row5_col35, #T_9925a_row5_col36, #T_9925a_row5_col37, #T_9925a_row5_col38, #T_9925a_row5_col39, #T_9925a_row5_col40, #T_9925a_row5_col41, #T_9925a_row5_col42, #T_9925a_row5_col43, #T_9925a_row5_col44, #T_9925a_row5_col45, #T_9925a_row5_col46, #T_9925a_row5_col47 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9925a_row2_col4, #T_9925a_row2_col10 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_9925a_row2_col6, #T_9925a_row2_col12 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_9925a_row2_col7, #T_9925a_row2_col13 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_9925a_row2_col9, #T_9925a_row2_col15 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_9925a_row3_col4, #T_9925a_row3_col10 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_9925a_row3_col6, #T_9925a_row3_col12 {
#   background-color: #a30f15;
#   color:

# %% [markdown]
# ### Creating a summary table for the most recent 'Egypt' data

# %%
df_egypt[['total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]]
# Out:
#       total_cases  new_cases  total_deaths  new_deaths
# 0             NaN        0.0           NaN         0.0
# 1             NaN        0.0           NaN         0.0
# 2             NaN        0.0           NaN         0.0
# 3             NaN        0.0           NaN         0.0
# 4             NaN        0.0           NaN         0.0
# ...           ...        ...           ...         ...
# 1494     516023.0        0.0       24830.0         0.0
# 1495     516023.0        0.0       24830.0         0.0
# 1496     516023.0        0.0       24830.0         0.0
# 1497     516023.0        0.0       24830.0         0.0
# 1498     516023.0        0.0       24830.0         0.0
#
# [1499 rows x 4 columns]

# %%
df_egypt_recent = df_egypt[df_egypt['date'] == df_egypt.date.max()]
df_egypt_recent
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1498      EGY    Africa    Egypt  2024-02-11     516023.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1498                 0.0       24830.0         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1498          50.1                  89.827                         1.6
#
#       life_expectancy  human_development_index   population  \
# 1498            71.99                    0.707  110990096.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1498                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1498               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_egypt_recent[['date','total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]]
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 1498  2024-02-11     516023.0        0.0       24830.0         0.0

# %% [markdown]
# ### Calculating the maximum values of 'Egypt' data|

# %%
df_egypt[['total_cases', 'new_cases', 'total_deaths', 'new_deaths' ]].max()
# Out:
# total_cases     516023.0
# new_cases        15872.0
# total_deaths     24830.0
# new_deaths         622.0
# dtype: float64

# %% [markdown]
# ### The highest date recorded for death in Egypt

# %%
df_egypt[df_egypt['total_cases'] == df_egypt['total_cases'].max()]
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1211      EGY    Africa    Egypt  2023-04-30     516023.0       27.0
# 1212      EGY    Africa    Egypt  2023-05-01     516023.0        0.0
# 1213      EGY    Africa    Egypt  2023-05-02     516023.0        0.0
# 1214      EGY    Africa    Egypt  2023-05-03     516023.0        0.0
# 1215      EGY    Africa    Egypt  2023-05-04     516023.0        0.0
# ...       ...       ...      ...         ...          ...        ...
# 1494      EGY    Africa    Egypt  2024-02-07     516023.0        0.0
# 1495      EGY    Africa    Egypt  2024-02-08     516023.0        0.0
# 1496      EGY    Africa    Egypt  2024-02-09     516023.0        0.0
# 1497      EGY    Africa    Egypt  2024-02-10     516023.0        0.0
# 1498      EGY    Africa    Egypt  2024-02-11     516023.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1211               3.857       24830.0         2.0                0.286  ...
# 1212               3.857       24830.0         0.0                0.286  ...
# 1213               3.857       24830.0         0.0                0.286  ...
# 1214               3.857       24830.0         0.0                0.286  ...
# 1215               3.857       24830.0         0.0                0.286  ...
# ...                  ...           ...         ...                  ...  ...
# 1494               0.000       24830.0         0.0                0.000  ...
# 1495               0.000       24830.0         0.0                0.000  ...
# 1496               0.000       24830.0         0.0                0.000  ...
# 1497               0.000       24830.0         0.0                0.000  ...
# 1498               0.000       24830.0         0.0                0.000  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1211          50.1                  89.827                         1.6
# 1212          50.1                  89.827                         1.6
# 1213          50.1                  89.827                         1.6
# 1214          50.1                  89.827                         1.6
# 1215          50.1                  89.827                         1.6
# ...            ...                     ...                         ...
# 1494          50.1                  89.827                         1.6
# 1495          50.1                  89.827                         1.6
# 1496          50.1                  89.827                         1.6
# 1497          50.1                  89.827                         1.6
# 1498          50.1                  89.827                         1.6
#
#       life_expectancy  human_development_index   population  \
# 1211            71.99                    0.707  110990096.0
# 1212            71.99                    0.707  110990096.0
# 1213            71.99                    0.707  110990096.0
# 1214            71.99                    0.707  110990096.0
# 1215            71.99                    0.707  110990096.0
# ...               ...                      ...          ...
# 1494            71.99                    0.707  110990096.0
# 1495            71.99                    0.707  110990096.0
# 1496            71.99                    0.707  110990096.0
# 1497            71.99                    0.707  110990096.0
# 1498            71.99                    0.707  110990096.0
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1211                             335928.25                        17.91
# 1212                                   NaN                          NaN
# 1213                                   NaN                          NaN
# 1214                                   NaN                          NaN
# 1215                                   NaN                          NaN
# ...                                    ...                          ...
# 1494                                   NaN                          NaN
# 1495                                   NaN                          NaN
# 1496                                   NaN                          NaN
# 1497                                   NaN                          NaN
# 1498                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1211              8.38                                2980.2908
# 1212               NaN                                      NaN
# 1213               NaN                                      NaN
# 1214               NaN                                      NaN
# 1215               NaN                                      NaN
# ...                ...                                      ...
# 1494               NaN                                      NaN
# 1495               NaN                                      NaN
# 1496               NaN                                      NaN
# 1497               NaN                                      NaN
# 1498               NaN                                      NaN
#
# [288 rows x 67 columns]

# %%
df_egypt[df_egypt['new_deaths'] == df_egypt['new_deaths'].max()]
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 168      EGY    Africa    Egypt  2020-06-21      53758.0    10778.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 168            1539.714        2106.0       622.0               88.857  ...
#
#      male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 168          50.1                  89.827                         1.6
#
#      life_expectancy  human_development_index   population  \
# 168            71.99                    0.707  110990096.0
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 168                                   NaN                          NaN
#
#      excess_mortality  excess_mortality_cumulative_per_million
# 168               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
df_egypt.loc[df_egypt['new_deaths'].idxmax()]['date']
# Out:
# '2020-06-21'

# %%
df_egypt[df_egypt['new_deaths'] == df_egypt['new_deaths'].max()]['date']
# Out:
# 168    2020-06-21
# Name: date, dtype: object

# %% [markdown]
# ### The average value(s) of daily-recorded data in Egypt

# %%
df_egypt['new_deaths'].mean()
# Out:
# 16.564376250833888

# %%
df_egypt['new_deaths'].describe()
# Out:
# count    1499.000000
# mean       16.564376
# std        70.244721
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       622.000000
# Name: new_deaths, dtype: float64

# %% [markdown]
# ### New cases of January 2021 in Egypt

# %% [markdown]
# # THANK YOU!
